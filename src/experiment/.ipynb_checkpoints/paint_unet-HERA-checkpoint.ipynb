# %%
#My Packages
from architectures.RNET import RNET7, RNET6, RNET5, RNET3
from architectures.UNET import UNET
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, Callback, LearningRateScheduler
from tensorflow.keras.initializers import TruncatedNormal, glorot_uniform
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as pltsplit_into_patchessplit_into_patches
from utils.data import load_hera_pickle, load_lofar_pickle, split_into_patches, normalize_patches
from architectures.RFDL import RFDL_RNET7, SIMPLE_UNET

# %%
def Conv2D_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, stride=(1,1)):
    # first layer
    x = layers.Conv2D(filters = n_filters, 
                      kernel_size = (kernel_size, kernel_size),\
                      kernel_initializer = 'he_normal', 
                      strides=stride,
                      padding = 'same')(input_tensor)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    return x

def corrupt_images(images):
    corrupted_images = images.copy()
    img_height, img_width = images.shape[1:3]

    for i in range(images.shape[0]):
        
        for _ in range(np.random.randint(0, 4)):
            brightness_factor = np.random.uniform(0.05, 0.20)
            orientation = np.random.choice(['horizontal', 'vertical'])
            line_width = np.random.randint(1, 4)

            if orientation == 'horizontal':
                x = np.random.randint(0, img_width - line_width + 1)
                corrupted_images[i, x:x+line_width, :, :] += brightness_factor
            else:
                y = np.random.randint(0, img_height - line_width + 1)
                corrupted_images[i, :, y:y+line_width, :] += brightness_factor

        # Add 0 to 3 dashed lines of corruption
        for _ in range(np.random.randint(1, 10)):
            brightness_factor = np.random.uniform(0.10, 0.50)
            orientation = np.random.choice(['horizontal', 'vertical'])
            line_width = np.random.randint(1, 2)
            dash_length = np.random.randint(1, img_width/2 + 1)
            gap_length = np.random.randint(1, img_width/4 + 1)
            if orientation == 'horizontal':
                x = np.random.randint(0, img_width - line_width + 1)
                y = 0
                while y < img_height:
                    corrupted_images[i, x:x+line_width, y:y+dash_length, :] += brightness_factor
                    y += dash_length + gap_length
            else:
                x = 0
                y = np.random.randint(0, img_height - line_width + 1)
                while x < img_width:
                    corrupted_images[i, x:x+dash_length, y:y+line_width, :] += brightness_factor
                    x += dash_length + gap_length

        # Add 0 to 3 small blocks of corruption
        for _ in range(np.random.randint(1, 3)):
            brightness_factor = np.random.uniform(0.10, 0.50)
            block_size = np.random.randint(2, 5)
            x = np.random.randint(0, img_width - block_size + 1)
            y = np.random.randint(0, img_height - block_size + 1)
            corrupted_images[i, x:x+block_size, y:y+block_size, :] += brightness_factor

    
    corruption_mask = corrupted_images - images

    # Identify the pixels to corrupt further with Gaussian noise
    to_corrupt = corruption_mask > 0

    # Generate Gaussian noise
    noise = np.random.normal(0, 0.1, corrupted_images.shape)

    # Apply the Gaussian noise only to the pixels identified by the corruption mask
    corrupted_images[to_corrupt] += noise[to_corrupt]

    # Ensure pixel values remain in the valid range [0, 1]
    corrupted_images = np.clip(corrupted_images, 0, 1)

    return corrupted_images

def gaussian_noise(data):
    mean = 0
    var = 10
    sigma = var**0.5
    noise = np.random.normal(mean, sigma, data.shape)
    noisy_data = np.clip(data + noise, 0, 1)  # Clip values to be in valid range
    return noisy_data

def flip(data, flip_type):
    if flip_type == 0:
        return np.flip(data, axis=1)  # Vertical flip
    elif flip_type == 1:
        return np.flip(data, axis=2)  # Horizontal flip
    elif flip_type == 2:
        return np.flip(np.flip(data, axis=1), axis=2)  # Both flips

def rotate(data, k):
    return np.rot90(data, k=k, axes=(1, 2))

def augment(data, mask):
    augmented_data = []
    augmented_masks = []

    for flip_type in range(3):  # 0: vertical, 1: horizontal, 2: both
        data_flipped = flip(data, flip_type)
        mask_flipped = flip(mask, flip_type)
        
        for k in range(4):  # 0: 0 degrees, 1: 90 degrees, 2: 180 degrees, 3: 270 degrees
            data_rotated = rotate(data_flipped, k)
            mask_rotated = rotate(mask_flipped, k)
            
            augmented_data.append(data_rotated)
            augmented_masks.append(mask_rotated)
    
    # Adding Gaussian noise to the augmented data
    # noisy_data = gaussian_noise(np.concatenate(augmented_data, axis=0))
    
    # Concatenating the noisy data with the original augmented data
    augmented_data = np.concatenate(augmented_data, axis=0)
    
    # Repeating the masks for the noisy data
    augmented_masks = np.concatenate(augmented_masks, axis=0)
    
    return augmented_data, augmented_masks

# %%
batch_sz = 64
data_path = "LOFAR"

#Load Training Data
X_train, y_train, X_test, y_test = load_lofar_pickle("../../data/HERA-SIM_Full_RFI_dataset.pkl", limit=1500)
y_train = y_train[:, :, :, np.newaxis]
print(y_train.shape)
X_train = (split_into_patches(X_train, batch_sz))
y_train = split_into_patches(y_train, batch_sz)
X_test = (split_into_patches(X_test, batch_sz))
y_test = split_into_patches(y_test, batch_sz)

normal_patches = np.where(np.all(y_train == 0, axis=(1,2,3)))[0]
X_train_normal = X_train[normal_patches]
X_train_normal = np.concatenate((X_train_normal, flip(X_train_normal,1)), axis=0)

X_train_corrupted = corrupt_images(X_train_normal)

X_noise = (X_train_corrupted - X_train_normal) > 0
y_train_combined = np.concatenate([X_train_normal, X_noise], axis=-1)
# Out:
# LOADING LOFAR DATASET FROM ../../data/HERA-SIM_Full_RFI_dataset.pkl
# SUCCESS
# PREPROCESSING...
# PREPROCESSING COMPLETE
# (960, 512, 512, 1)

# %%
# Shuffle the indices to get a random sample of images
shuffled_indices = np.random.permutation(len(X_train_normal))[:8]

# Plot the actual, corrupted, and inpainted images side by side
fig, axes = plt.subplots(8, 3, figsize=(24, 24))

# Adjust the margins between the subplots
plt.subplots_adjust(wspace=0.05, hspace=0.05)

for i, idx in enumerate(shuffled_indices):
    # Plot the actual image
    axes[i, 0].imshow(X_train_normal[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 0].axis('off')
    axes[i, 0].set_title(f'Normal {idx}')
    
    # Plot the actual image
    axes[i, 1].imshow(X_train_corrupted[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 1].axis('off')
    axes[i, 1].set_title(f'True {idx}')
    
    # Plot the actual image
    axes[i, 2].imshow((X_train_corrupted[idx] - X_train_normal[idx]).reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 2].axis('off')
    axes[i, 2].set_title(f'True {idx}')

plt.tight_layout()
plt.show()

# %%
unet = SIMPLE_UNET((64,64,1))
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
unet.fit(X_train_corrupted, y_train_combined, epochs=200, batch_size=128, validation_split=0.2, verbose=1, callbacks=[checkpoint])
unet.save('RFDL_UNET_SIMPLE_HERA.h5')
# Out:
# 2023-10-16 10:18:01.950419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:01.953769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:01.953895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:01.954310: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-16 10:18:01.954647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:01.954765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:01.954876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:02.271261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:02.271431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:02.271544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-16 10:18:02.271641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6654 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-16 10:18:02.658755: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2023-10-16 10:18:03.389151: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
# 2023-10-16 10:18:03.681062: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-16 10:18:03.681334: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-16 10:18:03.681352: W tensorflow/stream_executor/gpu/asm_compiler.cc:77] Couldn't get ptxas version string: Internal: Couldn't invoke ptxas --version
# 2023-10-16 10:18:03.681641: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-16 10:18:03.681690: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 62/62 [==============================] - 5s 50ms/step - loss: 0.0555 - val_loss: 0.0219
#
# Epoch 00001: val_loss improved from inf to 0.02191, saving model to best_model.h5
# Epoch 2/200
#  5/62 [=>............................] - ETA: 1s - loss: 0.0102
# /opt/conda/lib/python3.9/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0089 - val_loss: 0.0076
#
# Epoch 00002: val_loss improved from 0.02191 to 0.00756, saving model to best_model.h5
# Epoch 3/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0056 - val_loss: 0.0049
#
# Epoch 00003: val_loss improved from 0.00756 to 0.00487, saving model to best_model.h5
# Epoch 4/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0047 - val_loss: 0.0050
#
# Epoch 00004: val_loss did not improve from 0.00487
# Epoch 5/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0046 - val_loss: 0.0061
#
# Epoch 00005: val_loss did not improve from 0.00487
# Epoch 6/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0038 - val_loss: 0.0037
#
# Epoch 00006: val_loss improved from 0.00487 to 0.00372, saving model to best_model.h5
# Epoch 7/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0038 - val_loss: 0.0290
#
# Epoch 00007: val_loss did not improve from 0.00372
# Epoch 8/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0031 - val_loss: 0.0039
#
# Epoch 00008: val_loss did not improve from 0.00372
# Epoch 9/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0028 - val_loss: 0.0042
#
# Epoch 00009: val_loss did not improve from 0.00372
# Epoch 10/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0028 - val_loss: 0.0016
#
# Epoch 00010: val_loss improved from 0.00372 to 0.00161, saving model to best_model.h5
# Epoch 11/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0025 - val_loss: 0.0015
#
# Epoch 00011: val_loss improved from 0.00161 to 0.00154, saving model to best_model.h5
# Epoch 12/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0023 - val_loss: 0.0014
#
# Epoch 00012: val_loss improved from 0.00154 to 0.00141, saving model to best_model.h5
# Epoch 13/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0020 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00141 to 0.00124, saving model to best_model.h5
# Epoch 14/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0019 - val_loss: 0.0034
#
# Epoch 00014: val_loss did not improve from 0.00124
# Epoch 15/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0020 - val_loss: 0.0015
#
# Epoch 00015: val_loss did not improve from 0.00124
# Epoch 16/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0018 - val_loss: 0.0028
#
# Epoch 00016: val_loss did not improve from 0.00124
# Epoch 17/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00017: val_loss did not improve from 0.00124
# Epoch 18/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0018 - val_loss: 0.0011
#
# Epoch 00018: val_loss improved from 0.00124 to 0.00106, saving model to best_model.h5
# Epoch 19/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0017 - val_loss: 0.0029
#
# Epoch 00019: val_loss did not improve from 0.00106
# Epoch 20/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0016 - val_loss: 0.0028
#
# Epoch 00020: val_loss did not improve from 0.00106
# Epoch 21/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0016 - val_loss: 9.0920e-04
#
# Epoch 00021: val_loss improved from 0.00106 to 0.00091, saving model to best_model.h5
# Epoch 22/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0016 - val_loss: 0.0011
#
# Epoch 00022: val_loss did not improve from 0.00091
# Epoch 23/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0015 - val_loss: 0.0015
#
# Epoch 00023: val_loss did not improve from 0.00091
# Epoch 24/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 8.4904e-04
#
# Epoch 00024: val_loss improved from 0.00091 to 0.00085, saving model to best_model.h5
# Epoch 25/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00025: val_loss did not improve from 0.00085
# Epoch 26/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00026: val_loss did not improve from 0.00085
# Epoch 27/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 0.0032
#
# Epoch 00027: val_loss did not improve from 0.00085
# Epoch 28/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0013
#
# Epoch 00028: val_loss did not improve from 0.00085
# Epoch 29/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0013 - val_loss: 9.5991e-04
#
# Epoch 00029: val_loss did not improve from 0.00085
# Epoch 30/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0014
#
# Epoch 00030: val_loss did not improve from 0.00085
# Epoch 31/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0010
#
# Epoch 00031: val_loss did not improve from 0.00085
# Epoch 32/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0012 - val_loss: 7.5488e-04
#
# Epoch 00032: val_loss improved from 0.00085 to 0.00075, saving model to best_model.h5
# Epoch 33/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 7.8555e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
# Epoch 36/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 7.9119e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 7.7193e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0013 - val_loss: 8.3946e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 8.1084e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0013 - val_loss: 0.0053
#
# Epoch 00042: val_loss did not improve from 0.00075
# Epoch 43/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00043: val_loss did not improve from 0.00075
# Epoch 44/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 0.0015
#
# Epoch 00044: val_loss did not improve from 0.00075
# Epoch 45/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 7.1960e-04
#
# Epoch 00045: val_loss improved from 0.00075 to 0.00072, saving model to best_model.h5
# Epoch 46/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0014 - val_loss: 0.0012
#
# Epoch 00046: val_loss did not improve from 0.00072
# Epoch 47/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 9.9337e-04
#
# Epoch 00047: val_loss did not improve from 0.00072
# Epoch 48/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 9.7038e-04
#
# Epoch 00048: val_loss did not improve from 0.00072
# Epoch 49/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00049: val_loss did not improve from 0.00072
# Epoch 50/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 0.0013
#
# Epoch 00050: val_loss did not improve from 0.00072
# Epoch 51/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00051: val_loss did not improve from 0.00072
# Epoch 52/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 0.0013
#
# Epoch 00052: val_loss did not improve from 0.00072
# Epoch 53/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0011 - val_loss: 7.9674e-04
#
# Epoch 00053: val_loss did not improve from 0.00072
# Epoch 54/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 0.0020
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 4.9348e-04
#
# Epoch 00055: val_loss improved from 0.00072 to 0.00049, saving model to best_model.h5
# Epoch 56/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.8066e-04 - val_loss: 0.0040
#
# Epoch 00056: val_loss did not improve from 0.00049
# Epoch 57/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 4.0129e-04
#
# Epoch 00057: val_loss improved from 0.00049 to 0.00040, saving model to best_model.h5
# Epoch 58/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.3854e-04 - val_loss: 9.9293e-04
#
# Epoch 00058: val_loss did not improve from 0.00040
# Epoch 59/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 0.0012
#
# Epoch 00059: val_loss did not improve from 0.00040
# Epoch 60/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0010 - val_loss: 4.4900e-04
#
# Epoch 00060: val_loss did not improve from 0.00040
# Epoch 61/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 5.5677e-04
#
# Epoch 00061: val_loss did not improve from 0.00040
# Epoch 62/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0010 - val_loss: 6.3965e-04
#
# Epoch 00062: val_loss did not improve from 0.00040
# Epoch 63/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.7879e-04 - val_loss: 0.0010
#
# Epoch 00063: val_loss did not improve from 0.00040
# Epoch 64/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.9369e-04 - val_loss: 5.5779e-04
#
# Epoch 00064: val_loss did not improve from 0.00040
# Epoch 65/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.3367e-04 - val_loss: 0.0013
#
# Epoch 00065: val_loss did not improve from 0.00040
# Epoch 66/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 4.3873e-04
#
# Epoch 00066: val_loss did not improve from 0.00040
# Epoch 67/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.4344e-04 - val_loss: 5.0220e-04
#
# Epoch 00067: val_loss did not improve from 0.00040
# Epoch 68/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.9274e-04 - val_loss: 5.2576e-04
#
# Epoch 00068: val_loss did not improve from 0.00040
# Epoch 69/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.4971e-04 - val_loss: 0.0012
#
# Epoch 00069: val_loss did not improve from 0.00040
# Epoch 70/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.7179e-04 - val_loss: 4.6759e-04
#
# Epoch 00070: val_loss did not improve from 0.00040
# Epoch 71/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0011 - val_loss: 3.4702e-04
#
# Epoch 00071: val_loss improved from 0.00040 to 0.00035, saving model to best_model.h5
# Epoch 72/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.6221e-04 - val_loss: 0.0010
#
# Epoch 00072: val_loss did not improve from 0.00035
# Epoch 73/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.3206e-04 - val_loss: 5.0595e-04
#
# Epoch 00073: val_loss did not improve from 0.00035
# Epoch 74/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.1052e-04 - val_loss: 7.0851e-04
#
# Epoch 00074: val_loss did not improve from 0.00035
# Epoch 75/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00075: val_loss did not improve from 0.00035
# Epoch 76/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.9383e-04 - val_loss: 6.9248e-04
#
# Epoch 00076: val_loss did not improve from 0.00035
# Epoch 77/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.1647e-04 - val_loss: 5.2801e-04
#
# Epoch 00077: val_loss did not improve from 0.00035
# Epoch 78/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.2972e-04 - val_loss: 8.1472e-04
#
# Epoch 00078: val_loss did not improve from 0.00035
# Epoch 79/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.2029e-04 - val_loss: 9.3684e-04
#
# Epoch 00079: val_loss did not improve from 0.00035
# Epoch 80/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.8182e-04 - val_loss: 3.6554e-04
#
# Epoch 00080: val_loss did not improve from 0.00035
# Epoch 81/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.8732e-04 - val_loss: 8.0382e-04
#
# Epoch 00081: val_loss did not improve from 0.00035
# Epoch 82/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.8792e-04 - val_loss: 5.7404e-04
#
# Epoch 00082: val_loss did not improve from 0.00035
# Epoch 83/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.2793e-04 - val_loss: 0.0012
#
# Epoch 00083: val_loss did not improve from 0.00035
# Epoch 84/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.6279e-04 - val_loss: 0.0011
#
# Epoch 00084: val_loss did not improve from 0.00035
# Epoch 85/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.4086e-04 - val_loss: 3.3996e-04
#
# Epoch 00085: val_loss improved from 0.00035 to 0.00034, saving model to best_model.h5
# Epoch 86/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.6155e-04 - val_loss: 6.8989e-04
#
# Epoch 00086: val_loss did not improve from 0.00034
# Epoch 87/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.2711e-04 - val_loss: 5.9316e-04
#
# Epoch 00087: val_loss did not improve from 0.00034
# Epoch 88/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.9055e-04 - val_loss: 4.3865e-04
#
# Epoch 00088: val_loss did not improve from 0.00034
# Epoch 89/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 4.3177e-04
#
# Epoch 00089: val_loss did not improve from 0.00034
# Epoch 90/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9749e-04 - val_loss: 5.3527e-04
#
# Epoch 00090: val_loss did not improve from 0.00034
# Epoch 91/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.9834e-04 - val_loss: 9.4490e-04
#
# Epoch 00091: val_loss did not improve from 0.00034
# Epoch 92/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.2191e-04 - val_loss: 9.0894e-04
#
# Epoch 00092: val_loss did not improve from 0.00034
# Epoch 93/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.7085e-04 - val_loss: 0.0017
#
# Epoch 00093: val_loss did not improve from 0.00034
# Epoch 94/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 0.0014
#
# Epoch 00094: val_loss did not improve from 0.00034
# Epoch 95/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.6543e-04 - val_loss: 3.3852e-04
#
# Epoch 00095: val_loss improved from 0.00034 to 0.00034, saving model to best_model.h5
# Epoch 96/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5179e-04 - val_loss: 0.0012
#
# Epoch 00096: val_loss did not improve from 0.00034
# Epoch 97/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.9925e-04 - val_loss: 3.4174e-04
#
# Epoch 00097: val_loss did not improve from 0.00034
# Epoch 98/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5447e-04 - val_loss: 3.5968e-04
#
# Epoch 00098: val_loss did not improve from 0.00034
# Epoch 99/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.6795e-04 - val_loss: 0.0010
#
# Epoch 00099: val_loss did not improve from 0.00034
# Epoch 100/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.6836e-04 - val_loss: 0.0012
#
# Epoch 00100: val_loss did not improve from 0.00034
# Epoch 101/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5579e-04 - val_loss: 0.0015
#
# Epoch 00101: val_loss did not improve from 0.00034
# Epoch 102/200
# 62/62 [==============================] - 2s 35ms/step - loss: 0.0010 - val_loss: 9.0455e-04
#
# Epoch 00102: val_loss did not improve from 0.00034
# Epoch 103/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.5402e-04 - val_loss: 3.4890e-04
#
# Epoch 00103: val_loss did not improve from 0.00034
# Epoch 104/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9541e-04 - val_loss: 4.9393e-04
#
# Epoch 00104: val_loss did not improve from 0.00034
# Epoch 105/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.5457e-04 - val_loss: 4.8519e-04
#
# Epoch 00105: val_loss did not improve from 0.00034
# Epoch 106/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.4091e-04 - val_loss: 0.0014
#
# Epoch 00106: val_loss did not improve from 0.00034
# Epoch 107/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.8284e-04 - val_loss: 3.0179e-04
#
# Epoch 00107: val_loss improved from 0.00034 to 0.00030, saving model to best_model.h5
# Epoch 108/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0773e-04 - val_loss: 8.6862e-04
#
# Epoch 00108: val_loss did not improve from 0.00030
# Epoch 109/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.3357e-04 - val_loss: 6.7666e-04
#
# Epoch 00109: val_loss did not improve from 0.00030
# Epoch 110/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.7103e-04 - val_loss: 5.4917e-04
#
# Epoch 00110: val_loss did not improve from 0.00030
# Epoch 111/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.8631e-04 - val_loss: 5.1091e-04
#
# Epoch 00111: val_loss did not improve from 0.00030
# Epoch 112/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0012 - val_loss: 0.0063
#
# Epoch 00112: val_loss did not improve from 0.00030
# Epoch 113/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.7291e-04 - val_loss: 8.7906e-04
#
# Epoch 00113: val_loss did not improve from 0.00030
# Epoch 114/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5697e-04 - val_loss: 0.0017
#
# Epoch 00114: val_loss did not improve from 0.00030
# Epoch 115/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.0998e-04 - val_loss: 3.2585e-04
#
# Epoch 00115: val_loss did not improve from 0.00030
# Epoch 116/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0803e-04 - val_loss: 4.1930e-04
#
# Epoch 00116: val_loss did not improve from 0.00030
# Epoch 117/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5535e-04 - val_loss: 7.2651e-04
#
# Epoch 00117: val_loss did not improve from 0.00030
# Epoch 118/200
# 62/62 [==============================] - 2s 35ms/step - loss: 9.6849e-04 - val_loss: 9.2813e-04
#
# Epoch 00118: val_loss did not improve from 0.00030
# Epoch 119/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.7418e-04 - val_loss: 3.6208e-04
#
# Epoch 00119: val_loss did not improve from 0.00030
# Epoch 120/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.1329e-04 - val_loss: 3.1507e-04
#
# Epoch 00120: val_loss did not improve from 0.00030
# Epoch 121/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.8156e-04 - val_loss: 5.3301e-04
#
# Epoch 00121: val_loss did not improve from 0.00030
# Epoch 122/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.8976e-04 - val_loss: 9.5775e-04
#
# Epoch 00122: val_loss did not improve from 0.00030
# Epoch 123/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0619e-04 - val_loss: 0.0010
#
# Epoch 00123: val_loss did not improve from 0.00030
# Epoch 124/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.3644e-04 - val_loss: 5.6638e-04
#
# Epoch 00124: val_loss did not improve from 0.00030
# Epoch 125/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.6862e-04 - val_loss: 4.4218e-04
#
# Epoch 00125: val_loss did not improve from 0.00030
# Epoch 126/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6448e-04 - val_loss: 6.5089e-04
#
# Epoch 00126: val_loss did not improve from 0.00030
# Epoch 127/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0162e-04 - val_loss: 4.3916e-04
#
# Epoch 00127: val_loss did not improve from 0.00030
# Epoch 128/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9141e-04 - val_loss: 4.0676e-04
#
# Epoch 00128: val_loss did not improve from 0.00030
# Epoch 129/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.4264e-04 - val_loss: 7.3190e-04
#
# Epoch 00129: val_loss did not improve from 0.00030
# Epoch 130/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.6287e-04 - val_loss: 6.1409e-04
#
# Epoch 00130: val_loss did not improve from 0.00030
# Epoch 131/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.6425e-04 - val_loss: 7.2962e-04
#
# Epoch 00131: val_loss did not improve from 0.00030
# Epoch 132/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.0296e-04 - val_loss: 5.0255e-04
#
# Epoch 00132: val_loss did not improve from 0.00030
# Epoch 133/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.6395e-04 - val_loss: 3.5534e-04
#
# Epoch 00133: val_loss did not improve from 0.00030
# Epoch 134/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.3346e-04 - val_loss: 6.9010e-04
#
# Epoch 00134: val_loss did not improve from 0.00030
# Epoch 135/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.4129e-04 - val_loss: 8.8955e-04
#
# Epoch 00135: val_loss did not improve from 0.00030
# Epoch 136/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.8077e-04 - val_loss: 6.4678e-04
#
# Epoch 00136: val_loss did not improve from 0.00030
# Epoch 137/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9627e-04 - val_loss: 0.0010
#
# Epoch 00137: val_loss did not improve from 0.00030
# Epoch 138/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5680e-04 - val_loss: 0.0011
#
# Epoch 00138: val_loss did not improve from 0.00030
# Epoch 139/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.1126e-04 - val_loss: 9.5505e-04
#
# Epoch 00139: val_loss did not improve from 0.00030
# Epoch 140/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.4027e-04 - val_loss: 9.2559e-04
#
# Epoch 00140: val_loss did not improve from 0.00030
# Epoch 141/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.3791e-04 - val_loss: 6.2965e-04
#
# Epoch 00141: val_loss did not improve from 0.00030
# Epoch 142/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.8290e-04 - val_loss: 0.0011
#
# Epoch 00142: val_loss did not improve from 0.00030
# Epoch 143/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.1374e-04 - val_loss: 3.0761e-04
#
# Epoch 00143: val_loss did not improve from 0.00030
# Epoch 144/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.2153e-04 - val_loss: 5.4726e-04
#
# Epoch 00144: val_loss did not improve from 0.00030
# Epoch 145/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.0682e-04 - val_loss: 2.9242e-04
#
# Epoch 00145: val_loss improved from 0.00030 to 0.00029, saving model to best_model.h5
# Epoch 146/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.7157e-04 - val_loss: 4.4110e-04
#
# Epoch 00146: val_loss did not improve from 0.00029
# Epoch 147/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.8293e-04 - val_loss: 4.8791e-04
#
# Epoch 00147: val_loss did not improve from 0.00029
# Epoch 148/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.2851e-04 - val_loss: 5.0932e-04
#
# Epoch 00148: val_loss did not improve from 0.00029
# Epoch 149/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.2135e-04 - val_loss: 3.1165e-04
#
# Epoch 00149: val_loss did not improve from 0.00029
# Epoch 150/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.4962e-04 - val_loss: 7.3346e-04
#
# Epoch 00150: val_loss did not improve from 0.00029
# Epoch 151/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0299e-04 - val_loss: 0.0026
#
# Epoch 00151: val_loss did not improve from 0.00029
# Epoch 152/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.3959e-04 - val_loss: 4.1300e-04
#
# Epoch 00152: val_loss did not improve from 0.00029
# Epoch 153/200
# 62/62 [==============================] - 2s 34ms/step - loss: 6.8205e-04 - val_loss: 0.0011
#
# Epoch 00153: val_loss did not improve from 0.00029
# Epoch 154/200
# 62/62 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 3.0348e-04
#
# Epoch 00154: val_loss did not improve from 0.00029
# Epoch 155/200
# 62/62 [==============================] - 2s 34ms/step - loss: 6.9419e-04 - val_loss: 6.9109e-04
#
# Epoch 00155: val_loss did not improve from 0.00029
# Epoch 156/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.4034e-04 - val_loss: 0.0010
#
# Epoch 00156: val_loss did not improve from 0.00029
# Epoch 157/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.8916e-04 - val_loss: 4.4327e-04
#
# Epoch 00157: val_loss did not improve from 0.00029
# Epoch 158/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.1585e-04 - val_loss: 8.7437e-04
#
# Epoch 00158: val_loss did not improve from 0.00029
# Epoch 159/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.8585e-04 - val_loss: 0.0014
#
# Epoch 00159: val_loss did not improve from 0.00029
# Epoch 160/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.7955e-04 - val_loss: 0.0013
#
# Epoch 00160: val_loss did not improve from 0.00029
# Epoch 161/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0215e-04 - val_loss: 6.7537e-04
#
# Epoch 00161: val_loss did not improve from 0.00029
# Epoch 162/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.3090e-04 - val_loss: 0.0012
#
# Epoch 00162: val_loss did not improve from 0.00029
# Epoch 163/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.9141e-04 - val_loss: 7.4296e-04
#
# Epoch 00163: val_loss did not improve from 0.00029
# Epoch 164/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.5129e-04 - val_loss: 7.4405e-04
#
# Epoch 00164: val_loss did not improve from 0.00029
# Epoch 165/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6535e-04 - val_loss: 0.0015
#
# Epoch 00165: val_loss did not improve from 0.00029
# Epoch 166/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.8862e-04 - val_loss: 7.7758e-04
#
# Epoch 00166: val_loss did not improve from 0.00029
# Epoch 167/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6667e-04 - val_loss: 0.0010
#
# Epoch 00167: val_loss did not improve from 0.00029
# Epoch 168/200
# 62/62 [==============================] - 2s 34ms/step - loss: 9.1493e-04 - val_loss: 3.0027e-04
#
# Epoch 00168: val_loss did not improve from 0.00029
# Epoch 169/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.0123e-04 - val_loss: 3.3235e-04
#
# Epoch 00169: val_loss did not improve from 0.00029
# Epoch 170/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.6851e-04 - val_loss: 8.1413e-04
#
# Epoch 00170: val_loss did not improve from 0.00029
# Epoch 171/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6519e-04 - val_loss: 0.0010
#
# Epoch 00171: val_loss did not improve from 0.00029
# Epoch 172/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.9896e-04 - val_loss: 3.4125e-04
#
# Epoch 00172: val_loss did not improve from 0.00029
# Epoch 173/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.3038e-04 - val_loss: 7.9823e-04
#
# Epoch 00173: val_loss did not improve from 0.00029
# Epoch 174/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.3218e-04 - val_loss: 3.0764e-04
#
# Epoch 00174: val_loss did not improve from 0.00029
# Epoch 175/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.3570e-04 - val_loss: 6.8341e-04
#
# Epoch 00175: val_loss did not improve from 0.00029
# Epoch 176/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.9205e-04 - val_loss: 9.2153e-04
#
# Epoch 00176: val_loss did not improve from 0.00029
# Epoch 177/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.3946e-04 - val_loss: 6.2079e-04
#
# Epoch 00177: val_loss did not improve from 0.00029
# Epoch 178/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.6604e-04 - val_loss: 5.3955e-04
#
# Epoch 00178: val_loss did not improve from 0.00029
# Epoch 179/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.8707e-04 - val_loss: 3.8028e-04
#
# Epoch 00179: val_loss did not improve from 0.00029
# Epoch 180/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.0958e-04 - val_loss: 0.0013
#
# Epoch 00180: val_loss did not improve from 0.00029
# Epoch 181/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.5986e-04 - val_loss: 0.0021
#
# Epoch 00181: val_loss did not improve from 0.00029
# Epoch 182/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.5837e-04 - val_loss: 0.0015
#
# Epoch 00182: val_loss did not improve from 0.00029
# Epoch 183/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.5260e-04 - val_loss: 4.3428e-04
#
# Epoch 00183: val_loss did not improve from 0.00029
# Epoch 184/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.2529e-04 - val_loss: 2.8676e-04
#
# Epoch 00184: val_loss improved from 0.00029 to 0.00029, saving model to best_model.h5
# Epoch 185/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6876e-04 - val_loss: 9.7106e-04
#
# Epoch 00185: val_loss did not improve from 0.00029
# Epoch 186/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9493e-04 - val_loss: 3.0723e-04
#
# Epoch 00186: val_loss did not improve from 0.00029
# Epoch 187/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.1891e-04 - val_loss: 0.0016
#
# Epoch 00187: val_loss did not improve from 0.00029
# Epoch 188/200
# 62/62 [==============================] - 2s 35ms/step - loss: 8.0946e-04 - val_loss: 2.9568e-04
#
# Epoch 00188: val_loss did not improve from 0.00029
# Epoch 189/200
# 62/62 [==============================] - 2s 35ms/step - loss: 7.9961e-04 - val_loss: 2.8661e-04
#
# Epoch 00189: val_loss improved from 0.00029 to 0.00029, saving model to best_model.h5
# Epoch 190/200
# 62/62 [==============================] - 2s 34ms/step - loss: 6.9890e-04 - val_loss: 2.7943e-04
#
# Epoch 00190: val_loss improved from 0.00029 to 0.00028, saving model to best_model.h5
# Epoch 191/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6003e-04 - val_loss: 0.0012
#
# Epoch 00191: val_loss did not improve from 0.00028
# Epoch 192/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6144e-04 - val_loss: 0.0012
#
# Epoch 00192: val_loss did not improve from 0.00028
# Epoch 193/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.5108e-04 - val_loss: 6.6786e-04
#
# Epoch 00193: val_loss did not improve from 0.00028
# Epoch 194/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.7729e-04 - val_loss: 8.7393e-04
#
# Epoch 00194: val_loss did not improve from 0.00028
# Epoch 195/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.9578e-04 - val_loss: 2.7967e-04
#
# Epoch 00195: val_loss did not improve from 0.00028
# Epoch 196/200
# 62/62 [==============================] - 2s 35ms/step - loss: 6.9449e-04 - val_loss: 4.7081e-04
#
# Epoch 00196: val_loss did not improve from 0.00028
# Epoch 197/200
# 62/62 [==============================] - 2s 34ms/step - loss: 8.0318e-04 - val_loss: 2.8954e-04
#
# Epoch 00197: val_loss did not improve from 0.00028
# Epoch 198/200
# 62/62 [==============================] - 2s 34ms/step - loss: 6.8341e-04 - val_loss: 9.1478e-04
#
# Epoch 00198: val_loss did not improve from 0.00028
# Epoch 199/200
# 62/62 [==============================] - 2s 34ms/step - loss: 7.6438e-04 - val_loss: 2.9940e-04
#
# Epoch 00199: val_loss did not improve from 0.00028
# Epoch 200/200
# 62/62 [==============================] - 2s 35ms/step - loss: 6.9075e-04 - val_loss: 3.5935e-04
#
# Epoch 00200: val_loss did not improve from 0.00028

# %%
# unet = load_model("RFDL_UNET.h5", custom_objects={'weighted_mse': weighted_mse})

X_test_inpainted = unet.predict(X_test)

from scipy.ndimage import gaussian_filter
import numpy as np

def smooth_images(images):
    smoothed_images = np.empty_like(images)
    
    for i in range(images.shape[0]):
        smoothed_images[i] = gaussian_filter(images[i], sigma=1)
    
    return smoothed_images

# X_test_inpainted = smooth_images(X_test_inpainted)

X_diff = X_test - X_test_inpainted

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Calculate the MSE for each image in the test set
mse_values = [mean_squared_error(X_test[i].flatten(), X_test_inpainted[i].flatten()) for i in range(len(X_test))]

# Calculate the average MSE across all test images
average_mse = np.mean(mse_values)
print(f"Average MSE: {average_mse}")

# Shuffle the indices to get a random sample of images
shuffled_indices = np.random.permutation(len(X_test))[:16]

# Plot the actual, corrupted, and inpainted images side by side
fig, axes = plt.subplots(16, 4, figsize=(24, 48))

# Adjust the margins between the subplots
plt.subplots_adjust(wspace=0.05, hspace=0.05)

for i, idx in enumerate(shuffled_indices):
    # Plot the actual image
    axes[i, 0].imshow(X_test[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 0].axis('off')
    axes[i, 0].set_title(f'Actual {idx}')
    
    # Plot the actual image
    axes[i, 1].imshow(y_test[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 1].axis('off')
    axes[i, 1].set_title(f'True {idx}')
    
    # Plot the inpainted image
    axes[i, 2].imshow(X_test_inpainted[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 2].axis('off')
    axes[i, 2].set_title(f'Inpainted {idx}')
    
    # Plot the inpainted image
    axes[i, 3].imshow(X_diff[idx].reshape(batch_sz, batch_sz), cmap='gray', vmin=0, vmax=1)
    axes[i, 3].axis('off')
    axes[i, 3].set_title(f'Difference {idx}')

plt.tight_layout()
# Out:
# Average MSE: 0.0010639865649864078

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc, confusion_matrix, ConfusionMatrixDisplay, f1_score
from numpy import argmax

y_prob_flat = X_diff.reshape(-1,1)
y_true_flat = y_test.reshape(-1,1)

plt.figure(figsize=(8, 8))  # Adjust the figure size

precision, recall, thresholds = precision_recall_curve(y_true_flat, y_prob_flat)
auc_precision_recall = auc(recall, precision)
# convert to f score
fscore = (2 * precision * recall) / (precision + recall + 1e-22)
# locate the index of the largest f score
ix = argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))

plt.plot(recall, precision, label='BNET Precision Recall Curve')
plt.scatter(recall[ix], precision[ix], marker='o', color='red', label='F-Score={0:.6f}'.format(fscore[ix]))
plt.fill_between(recall, precision, alpha=0.2, label="AUPRC = {0:.6f}".format(auc_precision_recall))
plt.title("Precision Recall Curve", fontsize=22)
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.legend(fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# Best Threshold=0.067172, F-Score=0.855
